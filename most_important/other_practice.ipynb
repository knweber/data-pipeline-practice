# %%
from datetime import datetime

# %%
fruits = ["apple", "peach", "banana", "kiwi", "strawberry"]
nums = [7,1,36,11,4,9,27,3]
word = "congratulations"
sentence = "the quick brown fox"

# %%
sorted(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'peach', 'strawberry']

# %%
sorted(fruits, reverse=True)
# Out:
# ['strawberry', 'peach', 'kiwi', 'banana', 'apple']

# %%
sorted(fruits, key=lambda x: len(x))
# Out:
# ['kiwi', 'apple', 'peach', 'banana', 'strawberry']

# %%
sorted(fruits, key=lambda x: len(x), reverse=True)
# Out:
# ['strawberry', 'banana', 'apple', 'peach', 'kiwi']

# %%
sorted(nums)
# Out:
# [1, 3, 4, 7, 9, 11, 27, 36]

# %%
# nums = [7,1,36,11,4,9,27,3]
sorted(nums, reverse=True)
# Out:
# [36, 27, 11, 9, 7, 4, 3, 1]

# %%
nums2 = [x%2==0 for x in nums]
print(nums2)
# Out:
# [False, False, True, False, True, False, False, False]

# %%
# sentence = "the quick brown fox"

list(sentence) # by character

words = sentence.split()
print(words)
# Out:
# ['the', 'quick', 'brown', 'fox']

# %%
print(' '.join(words)) # back to actual sentence
# Out:
# the quick brown fox

# %%
joined_sorted = ' '.join(sorted(words))
print(joined_sorted)
# Out:
# brown fox quick the

# %%
delimited = "apple, banana, cherry"

print(delimited.split())
# Out:
# ['apple,', 'banana,', 'cherry']

# %%
print(delimited.split(','))
# Out:
# ['apple', ' banana', ' cherry']

# %%
delimited2 = "apple|banana|cherry"

print(delimited2.split('|'))
# Out:
# ['apple', 'banana', 'cherry']

# %%
now_obj = datetime.now()

formatted = datetime.strftime(now_obj, '%Y-%m-%d')
print(formatted)
# Out:
# 2026-07-25

# %%
today = '2026-07-25'

obj = datetime.strptime(today,'%Y-%m-%d')
print(obj)
# Out:
# 2026-07-25 00:00:00

# %%
today2 = '7/25/2026'

obj2 = datetime.strptime(today2, '%m/%d/%Y')
print(obj2)
# Out:
# 2026-07-25 00:00:00

# %%
print(' | '.join(str(num) for num in nums))
# Out:
# 7 | 1 | 36 | 11 | 4 | 9 | 27 | 3

# %%
print(sentence)

print(sentence.replace('fox', 'horse'))
# Out:
# the quick brown fox
# the quick brown horse

# %%
print(fruits)

fruits_safe = fruits

fruits2 = ['mango', 'orange']

fruits_safe.extend(fruits2)

print(fruits_safe)
# Out:
# ['apple', 'peach', 'banana', 'kiwi', 'strawberry']
# ['apple', 'peach', 'banana', 'kiwi', 'strawberry', 'mango', 'orange']

# %%
cities_states = {
    "Seattle": "WA",
    "Portland": "OR",
    "San Francisco": "CA",
    "Boston": "MA",
    "New York City": "NY"
}

# %%
print(cities_states.keys())
# Out:
# dict_keys(['Seattle', 'Portland', 'San Francisco', 'Boston', 'New York City'])

# %%
print(cities_states.values())
# Out:
# dict_values(['WA', 'OR', 'CA', 'MA', 'NY'])

# %%
print(cities_states.items())
# Out:
# dict_items([('Seattle', 'WA'), ('Portland', 'OR'), ('San Francisco', 'CA'), ('Boston', 'MA'), ('New York City', 'NY')])

# %%
cities_states.get("Seattle")
# Out:
# 'WA'

# %%
cities = list(cities_states.keys())
print(cities)
# Out:
# ['Seattle', 'Portland', 'San Francisco', 'Boston', 'New York City']

# %%
cities_lower = list(map(lambda x: x.lower(), cities))
print(cities_lower)
# Out:
# ['seattle', 'portland', 'san francisco', 'boston', 'new york city']

# %%
citieslower = [x.lower() for x in cities]
print(citieslower)
# Out:
# ['seattle', 'portland', 'san francisco', 'boston', 'new york city']
