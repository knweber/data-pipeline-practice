# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
import os
import sys

# 1. Force Python to find your Homebrew OpenJDK 11 path
os.environ["JAVA_HOME"] = "/opt/homebrew/opt/openjdk@17"

# 2. Tell PySpark exactly which Python executable to map to the JVM
os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("ETL_Test") \
    .getOrCreate()

print("Spark Session Created Successfully!")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/26 10:13:54 WARN Utils: Your hostname, Kristiannas-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.4.47 instead (on interface en0)
# 26/07/26 10:13:54 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyspark/testing/utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# ...

# %%
#spark = SparkSession.builder.appName("ETLPipeline").getOrCreate()

df = spark.read.parquet("../sample_data/titanic.parquet")
print("Loaded from parquet file")
transformed_df = df.withColumn("Alive", F.when(F.col("Survived") == "1", "Yes").otherwise("No"))

print("Loading to parquet file")
transformed_df.write.mode("overwrite").parquet("../output/pyspark_titanic.parquet")
print("Succeeded")
# Out:
# Loaded from parquet file
# Loading to parquet file
# Succeeded

# %%
df2 = spark.read.parquet("../output/pyspark_titanic.parquet")
print(df2.head())
# Out:
# Row(PassengerId=1, Survived=0, Pclass=3, Name='Braund, Mr. Owen Harris', Sex='male', Age=22.0, SibSp=1, Parch=0, Ticket='A/5 21171', Fare=7.25, Cabin=None, Embarked='S', Alive='No')
